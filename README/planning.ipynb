# %% [markdown]
# notebook:
# 1. Scoring proposal
# 2. Analysis of each section of the survey
# 3. Total analysis, interpretations
#
# Data:
# 1. example data
#
# Src:
# 1. explanations of example data
# 2. explanation of data cleaning
